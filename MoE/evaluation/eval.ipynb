# %%
# Out:
# Failed to start the Kernel '.llm (Python 3.10.12)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Cannot find module '@jupyterlab/services'
#
# Require stack:
#
# - /home/feihm/.vscode-server/extensions/ms-toolsai.jupyter-2025.8.0-linux-x64/dist/extension.node.js
#
# - /home/feihm/.vscode-server/extensions/ms-toolsai.jupyter-2025.8.0-linux-x64/dist/extension.node.proxy.js
#
# - /home/feihm/.vscode-server/cli/servers/Stable-f220831ea2d946c0dcb0f3eaa480eb435a2c1260/server/out/vs/workbench/api/node/extensionHostProcess.js
